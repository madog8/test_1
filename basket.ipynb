# %%
import pandas as pd

# %%
df = pd.read_excel('db_main_12_2023.xlsx', index_col=0)

# %%
df = df[~df.index.str.contains("\(ж\)")]

# %%
df.insert(df.columns.get_loc('raz_tf-t4q') + 1, 'rezult', '')

# %%
df
# Out:
#                                                      data_game time_match  \
# Минск — Пари Нижний Новгород                        01.10.2023      14:00
# Руна — Автодор                                      01.10.2023      16:00
# Шоле — Бриндизи                                     01.10.2023      18:30
# Борац Чачак — Цибона                                01.10.2023      19:00
# Ховентут Бадалона — Гран Канария                    01.10.2023      13:30
# ...                                                        ...        ...
# Хай Пойнт Пантерс (студ) — Саут Каролина Апстей...  14.02.2024      03:00
# Бостон Селтикс — Бруклин Нетс                       15.02.2024        NaN
# Риачуэло де Ла Риоха — Сарате Баскет                14.02.2024      04:00
# Мюррей Стэйт (студ) — Миссури Стэйт (студ)          14.02.2024      04:00
# Вальпараисо Беаконс (студ) — Нортерн Айова (студ)   14.02.2024      04:00
#
# ...

# %%
# Out:
# array(['Лига ВТБ', 'Лига Чемпионов. Отборочные матчи. Серик',
#        'Адриатическая лига', 'Испания. ACB League', 'Евролига ULEB',
#        'Италия. Серия А', 'Германия. Бундеслига', 'Турция. Суперлига',
#        'Франция. Про А', 'Литва. LKL', 'Чехия. NBL',
#        'Австрия. Суперкубок', 'Австрия. Кубок', 'Австрия. Суперлига',
#        'Бразилия. NBB', 'Великобритания. BBL', 'Дания. Баскетлиган',
#        'Болгария. Чемпионат', 'BNXT Лига', 'Германия. Про А',
#        'Италия. Серия А2', 'Латвийско-Эстонская Баскетбольная Лига',
#        'Италия. Серия В', 'Швеция. Суперэттан', 'Польша. 1-я лига',
#        'Словакия. Экстралига', 'Турция. 1-я лига', 'Чехия. 1-я лига',
#        'Швейцария. SBL', 'Уганда. Чемпионат', 'Норвегия. BLNO',
#        'Ирак. Премьер-лига', nan,
#        'Лига Чемпионов. Отборочные матчи. Анталья',
#        'Греция. Basket League', 'Польша. Экстралига',
#        'Бельгия. 1-й дивизион', 'Венгрия. Чемпионат. НБ1/А',
# ...
